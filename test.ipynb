# %%
from thumbs.data import get_pokemon_data

images = get_pokemon_data()
# Out:
# 2023-06-15 12:59:51.032702: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Images in /home/anthony/workspace/yt-data/pokemon
# ['panpour.png:Zone.Identifier', 'sableye.png:Zone.Identifier', 'emolga.png.jpg', 'slurpuff.png:Zone.Identifier', 'roserade.png.jpg', 'grubbin.jpg', 'pyroar.png', 'darumaka.png:Zone.Identifier', 'prinplup.png', 'amaura.png']
# Found 2339 total files
# Found 809 jpgs
# 100%|██████████| 809/809 [00:00<00:00, 1972.40it/s]
# 2023-06-15 12:59:52.820889: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...
